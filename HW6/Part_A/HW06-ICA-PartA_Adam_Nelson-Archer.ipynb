# %% [markdown]
# # HW06-ICA Part A :: Binary Classification Metrics
#
# COSC 6373 -- Adam Nelson-Archer, 2140122

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50

print("TensorFlow:", tf.__version__)

model = ResNet50(weights="imagenet")
# Out:
# TensorFlow: 2.16.1

# %%
print("Model name:", model.name)
print("Num weights tensors:", len(model.weights))
print("First weight tensor shape:", model.weights[0].shape)
assert len(model.weights) > 0
# Out:
# Model name: resnet50
# Num weights tensors: 320
# First weight tensor shape: (7, 7, 3, 64)

# %% [markdown]
# ## Acknowledgment
#
# I used a coding assistant (ChatGPT, GPT‑5.2) to review my code cell and formatting.
